# %%
N=int(input())

for i in range(N):
    print(" "*i+"*"*(N-i)+"*"*(N-i-1))
for i in range(2,N+1):
    print(" "*(N-i)+"*"*i+"*"*(i-1))
# Out:
# *********
#  *******
#   *****
#    ***
#     *
#    ***
#   *****
#  *******
# *********
