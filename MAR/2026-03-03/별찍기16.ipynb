# %%
N=int(input())

for i in range(1,N+1):
    print(" "*(N-i)+"*"*i)
# Out:
#   *
#  **
# ***

# %%
N = int(input())

for i in range(N):
    print(' ' * (N - 1 - i) + ' '.join(['*'] * (i + 1)))
# Out:
#   *
#  * *
# * * *
