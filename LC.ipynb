# %%
# 1
# 2
# 3
# 4
# 5

# A= [int(input()) for _ in range(5)]
# print(A)


# 1 2 3
# 4 5 6

[1,2,3],[4,5,6]
A=[list(map(int,input().split())) for _ in range(2)]
print(A)
int(input())

a,b = map(int,input().split())

a = list(map(int,input().split()))

for _ in
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
N=int(input())
print(x)
print(N,A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 N=int(input())
# ----> 2 A=[x for _ in range(N) if (x:= x%2==0)]
#       3 print(x)
#       4 print(N,A)
#
# NameError: name 'x' is not defined

# %%
A,B,C,D=map(int,input().split())

# %%
A=[x for _ in range(N) if (x:= x%2==0)]
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 A=[x for _ in range(N) if (x:= x%2==0)]
#       2 print(A)
#
# NameError: name 'x' is not defined
